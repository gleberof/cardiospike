# %%
import pandas as pd
import numpy as np
import plotly.graph_objs as go
from cardiospike.utils.visualization import plot_rr
from cardiospike import TEST_DATA_PATH, DB_COLORS

# %%
data = pd.read_csv(TEST_DATA_PATH)
sample = "176"
t = data.loc[data["id"] == int(sample)].sort_values("time").reset_index(drop=True)
t["anomaly_proba"] = np.random.rand(len(t)) / 1.3
t["error_proba"] = np.random.rand(len(t))

# %%
plot_rr(t)
# Out:
# <div>                            <div id="702bb240-2f9f-45c7-ad5e-36eac7a816e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("702bb240-2f9f-45c7-ad5e-36eac7a816e4")) {                    Plotly.newPlot(                        "702bb240-2f9f-45c7-ad5e-36eac7a816e4",                        [{"line": {"color": "#e83e8c", "width": 3}, "name": "RR Interval", "type": "scatter", "x": [0, 1240, 1864, 2488, 3108, 3724, 4340, 4964, 5576, 6192, 6808, 7424, 8048, 8724, 9284, 9900, 10528, 11156, 11780, 12396, 13024, 13708, 14280, 14964, 15532, 16160, 16788, 17476, 18044, 18724, 19292, 19976, 20544, 21164, 21788, 22472, 23036, 23712, 24276, 24952, 25520, 26140, 26764, 27444, 28020, 29276, 29956, 30532, 31160, 31788, 32412, 33040, 33728, 34300, 34924, 35552, 361
# ...
